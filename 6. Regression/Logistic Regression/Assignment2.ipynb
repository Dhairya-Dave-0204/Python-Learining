# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score

# %%
df = pd.read_csv("./Diabetes_Dataset.csv")

# %% [markdown]
# ## 1. Understanding the dataset

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'diabetes'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pregnancies  768 non-null    int64
#  1   glucose      768 non-null    int64
#  2   diastolic    768 non-null    int64
#  3   triceps      768 non-null    int64
#  4   insulin      768 non-null    int64
#  5   bmi          768 non-null    float64
#  6   dpf          768 non-null    float64
#  7   age          768 non-null    int64
#  8   diabetes     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# pregnancies    0
# glucose        0
# diastolic      0
# triceps        0
# insulin        0
# bmi            0
# dpf            0
# age            0
# diabetes       0
# dtype: int64

# %%
df.describe()
# Out:
#        pregnancies     glucose   diastolic     triceps     insulin  \
# count   768.000000  768.000000  768.000000  768.000000  768.000000
# mean      3.845052  120.894531   69.105469   20.536458   79.799479
# std       3.369578   31.972618   19.355807   15.952218  115.244002
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       1.000000   99.000000   62.000000    0.000000    0.000000
# 50%       3.000000  117.000000   72.000000   23.000000   30.500000
# 75%       6.000000  140.250000   80.000000   32.000000  127.250000
# max      17.000000  199.000000  122.000000   99.000000  846.000000
#
#               bmi         dpf         age    diabetes
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# ...

# %%
for col in df.columns:
    plt.boxplot(x=df[col])
    plt.title(f"Plot for {col}")
    plt.show()

# %%
for col in df.columns:
    sns.histplot(df[col], kde=True)
    plt.title(f"Histogram for {col}")
    plt.show()

# %% [markdown]
# ## 2. Preparing the data for the model

# %%
X= df.drop("diabetes", axis=1)
y = df["diabetes"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ## 3. Checking the parameters of hte model

# %%
y_pred = model.predict(X_test)
y_pred_prob = model.predict_proba(X_test)[:, 1]

print("Accuracy score: ", accuracy_score(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
print("\n Confusion matrix: \n ", cm)

print("Classification Report: \n", classification_report(y_test, y_pred))

roc_auc = roc_auc_score(y_test, y_pred_prob)
print("ROC AUC: ", roc_auc)

plt.figure(figsize=(8,7))
sns.heatmap(cm, annot=True, cmap="coolwarm")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy score:  0.7467532467532467
#
#  Confusion matrix:
#   [[78 21]
#  [18 37]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80        99
#            1       0.64      0.67      0.65        55
#
#     accuracy                           0.75       154
#    macro avg       0.73      0.73      0.73       154
# weighted avg       0.75      0.75      0.75       154
#
# ROC AUC:  0.8128558310376492

# %% [markdown]
# ## 4. Inference from the model

# %%
df.describe()
# Out:
#        pregnancies     glucose   diastolic     triceps     insulin  \
# count   768.000000  768.000000  768.000000  768.000000  768.000000
# mean      3.845052  120.894531   69.105469   20.536458   79.799479
# std       3.369578   31.972618   19.355807   15.952218  115.244002
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       1.000000   99.000000   62.000000    0.000000    0.000000
# 50%       3.000000  117.000000   72.000000   23.000000   30.500000
# 75%       6.000000  140.250000   80.000000   32.000000  127.250000
# max      17.000000  199.000000  122.000000   99.000000  846.000000
#
#               bmi         dpf         age    diabetes
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# ...

# %%
df.columns
# Out:
# Index(['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'diabetes'],
#       dtype='str')

# %%
# Very High risk data 
new_data = pd.DataFrame({
    "pregnancies": [10],
    "glucose": [220],
    "diastolic": [110],
    "triceps": [50],
    "insulin": [350],
    "bmi": [45.0],
    "dpf": [2.00],
    "age": [65]
})

probablity = model.predict_proba(new_data)[:, 1][0]
prediction = model.predict(new_data)[0]

print("Predicted probability of Diabetes: ", probablity)
print("Predicted class (0 = No Diabetes & 1 = Diabetes): ", prediction)
# Out:
# Predicted probability of Diabetes:  0.9956209925596372
# Predicted class (0 = No Diabetes & 1 = Diabetes):  1

# %%
# Medium risk data

new_data = pd.DataFrame({
    "pregnancies": [3],
    "glucose": [130],
    "diastolic": [80],
    "triceps": [30],
    "insulin": [150],
    "bmi": [31.5],
    "dpf": [0.65],
    "age": [40]
})

probablity = model.predict_proba(new_data)[:, 1][0]
prediction = model.predict(new_data)[0]

print("Predicted probability of Diabetes: ", probablity)
print("Predicted class (0 = No Diabetes & 1 = Diabetes): ", prediction)
# Out:
# Predicted probability of Diabetes:  0.368160347651311
# Predicted class (0 = No Diabetes & 1 = Diabetes):  0

# %%
# Low risk data

new_data = pd.DataFrame({
    "pregnancies": [1],
    "glucose": [95],
    "diastolic": [70],
    "triceps": [20],
    "insulin": [80],
    "bmi": [22.5],
    "dpf": [0.25],
    "age": [25]
})

probablity = model.predict_proba(new_data)[:, 1][0]
prediction = model.predict(new_data)[0]

print("Predicted probability of Diabetes: ", probablity)
print("Predicted class (0 = No Diabetes & 1 = Diabetes): ", prediction)
# Out:
# Predicted probability of Diabetes:  0.033548654509967295
# Predicted class (0 = No Diabetes & 1 = Diabetes):  0
