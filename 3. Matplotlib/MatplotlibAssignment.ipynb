# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 1.	Write Python code to plot a simple line graph using x = [1, 2, 3, 4, 5] and y = [2, 4, 6, 8, 10].

# %%
x = [1, 2, 3, 4, 5] 
y = [2, 4, 6, 8, 10]

plt.plot(x,y)
plt.show()

# %% [markdown]
# 2.	Plot a line graph showing squares of numbers from 1 to 5.

# %%
x = [1, 2, 3, 4, 5] 
y = [1, 4, 9, 16, 25]

plt.plot(x, y)
plt.xlabel("Numbers")
plt.ylabel("squares")
plt.show()

# %% [markdown]
# 3.	Plot a line graph showing cubes of numbers from 1 to 5.

# %%
x = [1, 2, 3, 4, 5]
y = [1, 2, 27, 64, 125]

plt.plot(x, y)
plt.xlabel("Numbers")
plt.ylabel("Cubes")
plt.show()

# %% [markdown]
# 4.	Create a line plot and add a title "My First Line Plot".

# %%
plt.plot(x,y)
plt.title("My First Line Plot")
plt.show()

# %% [markdown]
# 5.	Create a line plot and label the x-axis as "X Axis" and y-axis as "Y Axis".

# %%
plt.plot(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# 6.	Plot a line graph using red color.

# %%
plt.plot(x, y, color="red")
plt.show()

# %% [markdown]
# 6.	Plot a line graph using red color.

# %%
plt.plot(x, y, marker="o")
plt.show()

# %% [markdown]
# 8.	Plot two line graphs on the same figure using different colors.

# %%
x = [1, 2, 3, 4, 5] 
y1 = [1, 4, 9, 16, 25]
y2 = [1, 2, 27, 64, 125]

plt.plot(x, y1, color="green")
plt.plot(x, y2, color="red")

plt.show()

# %% [markdown]
# 9.	Plot two line graphs and add a legend to the graph.

# %%
plt.plot(x, y1, label="Line1")
plt.plot(x, y2, label="Line2")
plt.legend()

plt.show()

# %% [markdown]
# 10.	Plot a line graph and display it using plt.show().

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# 11.	Write code to create a bar chart using subjects = ['Math', 'Science', 'English'] marks = [80, 70, 90].

# %%
subjects = ['Math', 'Science', 'English'] 
marks = [80, 70, 90]

plt.bar(subjects, marks)
plt.show()

# %% [markdown]
# 12.	Create a bar chart and set the color of bars to green.

# %%
plt.bar(subjects, marks, color="green")
plt.show()

# %% [markdown]
# 13.	Create a bar chart and give it the title "Student Marks".

# %%
plt.bar(subjects, marks)
plt.title("Student Marks")
plt.show()

# %% [markdown]
# 14.	Create a bar chart and label x-axis and y-axis.

# %%
plt.bar(subjects, marks)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# 15.	Create a bar chart showing sales data of products.

# %%
proudcts = ["Watches", "Perfumes", "Shoes"]
sales = [500, 797, 623]

plt.bar(proudcts, sales, width=0.5)
plt.title("Sales data")
plt.xlabel("Products")
plt.ylabel("Sales (Quantity)")

plt.show()

# %% [markdown]
# 16.	Create a bar chart using custom width.

# %%
plt.bar(subjects, marks, width=0.3)
plt.show()

# %% [markdown]
# 17.	Create a bar chart using different colors for bars.

# %%
plt.bar(subjects, marks, color=["red", "green", "#000000"])
plt.show()

# %% [markdown]
# 18.	Display the bar chart using plt.show().

# %%
plt.bar(subjects, marks)
plt.show()

# %% [markdown]
# 19.	Write code to create a histogram using data = [10, 20, 20, 30, 40, 40, 40, 50].

# %%
data = [10, 20, 20, 30, 40, 40, 40, 50]

plt.hist(data, bins=3, edgecolor="#000")
plt.show()

# %% [markdown]
# 20.	Create a histogram with 5 bins.

# %%
plt.hist(data, bins=5, edgecolor="#0A0341")
plt.show()

# %% [markdown]
# 21.	Create a histogram with red color.

# %%
plt.hist(data, bins=5, edgecolor="#000", color="red")
plt.show()

# %% [markdown]
# 22.	Create a histogram and add a title.

# %%
plt.hist(data, bins=5, edgecolor="#000")
plt.title("Demo Histogram")
plt.show()

# %% [markdown]
# 23.	Create a histogram and label x-axis and y-axis.

# %%
plt.hist(data, bins=5, edgecolor="#000")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# 24.	Create a histogram using random values.

# %%
randomHist = np.random.randint(1, 100, 40)

plt.hist(randomHist, bins=6, edgecolor="#000")
plt.show()

# %% [markdown]
# 25.	Display the histogram using plt.show().

# %%
plt.hist(data, bins=5, edgecolor="#000")
plt.show()

# %% [markdown]
# 26.	Write code to create a pie chart using labels = ['Python', 'Java', 'C++'] sizes = [50, 30, 20].

# %%
labels = ['Python', 'Java', 'C++'] 
sizes = [50, 30, 20]

plt.pie(sizes, labels=labels)
plt.show()

# %% [markdown]
# 27.	Create a pie chart with percentage display.

# %%
plt.pie(sizes, labels=labels, autopct="%1.1f%%")
plt.show()

# %% [markdown]
# 28.	Create a pie chart with start angle.

# %%
plt.pie(sizes, labels=labels, startangle=90)
plt.show()

# %% [markdown]
# 29.	Create a pie chart with shadow.

# %%
plt.pie(sizes, labels=labels, shadow=True)
plt.show()

# %% [markdown]
# 30.	Add title to a pie chart.

# %%
plt.pie(sizes, labels=labels)
plt.title("Demo pie chart")
plt.show()

# %% [markdown]
# 31.	Display the pie chart using plt.show().

# %%
plt.pie(sizes, labels=labels)
plt.show()

# %% [markdown]
# 32.	Write code to create a scatter plot using x = [1, 2, 3, 4, 5] y = [5, 4, 3, 2, 1].

# %%
x = [1, 2, 3, 4, 5] 
y = [5, 4, 3, 2, 1]

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# 33.	Create a scatter plot with red color.

# %%
plt.scatter(x, y, color="red")
plt.show()

# %% [markdown]
# 34.	Create a scatter plot using square markers.

# %%
plt.scatter(x, y, marker="s")
plt.show()

# %% [markdown]
# 35.	Create a scatter plot and add a title.

# %%
plt.scatter(x, y)
plt.title("Demo scatter graph")
plt.show()

# %% [markdown]
# 36.	Create a scatter plot and label x and y axes.

# %%
plt.scatter(x, y)
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# 37.	Create a scatter plot using different sizes.

# %%
sizes = [10, 40, 90, 130, 500]

plt.scatter(x, y, s=sizes)
plt.show()

# %% [markdown]
# 38.	Display the scatter plot using plt.show().

# %%
plt.scatter(x, y)
plt.show()
